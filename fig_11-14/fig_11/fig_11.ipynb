# %% [markdown]
# # HF TDOA Analysis - Figures 11
#
# This notebook uses the `hf_tdoa` library to analyze HF TDOA measurements.

# %%
import os
import hf_tdoa as tdoa

# %matplotlib inline

# Setup plotting style
tdoa.setup_plotting_style()

# %% [markdown]
# ## Load WAV Files & Find Chirps

# %%
base_dir   = '../data'
data_set   = 'TX_WA5FRF_EL09nn-RX_N5DUP_EM02ch-40m'
sweep_rate = 10  # Hz/ms

# Path to chirp template - used for finding chirp locations via cross-correlation
template   = os.path.join('../templates', 'N6RFM_10Hz_per_ms_template.wav')

data_dir   = os.path.join(base_dir, data_set)
wavlist    = tdoa.obtain_wav_list(data_dir)

# %%
# Correlate each WAV with a known template chirp to identify chirp locations in each WAV file.
chirps = tdoa.find_chirps(wavlist, template, sweep_rate=sweep_rate, plot_correlation=False)
# Out:
# ======================================================================
# Finding Chirps via Cross-Correlation
# ======================================================================
#   Path Info:      PathInfo(TX: WA5FRF (EL09nn), RX: N5DUP (EM02ch), Range: 318.0 km, Band: 7 MHz)
#   Template:       N6RFM_10Hz_per_ms_template.wav
#   Sweep Rate:     10 Hz/ms
#   Files to Process: 32
#   Chirps per File: Top 10
# ======================================================================
# Finding chirps:   0%|          | 0/32 [00:00<?, ?file/s]
# Finding chirps:   0%|          | 0/32 [00:00<?, ?file/s, Chirps=10, Max Corr=5.25e+02]
# Finding chirps:   0%|          | 0/32 [00:00<?, ?file/s, Chirps=10, Max Corr=4.53e+02]
# Finding chirps:   6%|▋         | 2/32 [00:00<00:01, 18.10file/s, Chirps=10, Max Corr=4.53e+02]
# Finding chirps:   6%|▋         | 2/32 [00:00<00:01, 18.10file/s, Chirps=10, Max Corr=5.07e+02]
# Finding chirps:   6%|▋         | 2/32 [00:00<00:01, 18.10file/s, Chirps=10, Max Corr=4.90e+02]
# Finding chirps:  12%|█▎        | 4/32 [00:00<00:01, 18.34file/s, Chirps=10, Max Corr=4.90e+02]
# Finding chirps:  12%|█▎        | 4/32 [00:00<00:01, 18.34file/s, Chirps=10, Max Corr=5.08e+02]
# Finding chirps:  12%|█▎        | 4/32 [00:00<00:01, 18.34file/s, Chirps=10, Max Corr=5.16e+02]
# Finding chirps:  12%|█▎        | 4/32 [00:00<00:01, 18.34file/s, Chirps=10, Max Corr=4.92e+02]
# Finding chirps:  22%|██▏       | 7/32 [00:00<00:01, 20.25file/s, Chirps=10, Max Corr=4.92e+02]
# Finding chirps:  22%|██▏       | 7/32 [00:00<00:01, 20.25file/s, Chirps=10, Max Corr=5.56e+02]
# Finding chirps:  22%|██▏       | 7/32 [00:00<00:01, 20.25file/s, Chirps=10, Max Corr=5.09e+02]
# Finding chirps:  22%|██▏       | 7/32 [00:00<00:01, 20.25file/s, Chirps=10, Max Corr=5.09e+02]
# Finding chirps:  31%|███▏      | 10/32 [00:00<00:01, 20.15file/s, Chirps=10, Max Corr=5.09e+02]
# Finding chirps:  31%|███▏      | 10/32 [00:00<00:01, 20.15file/s, Chirps=10, Max Corr=4.98e+02]
# Finding chirps:  31%|███▏      | 10/32 [00:00<00:01, 20.15file/s, Chirps=10, Max Corr=5.01e+02]
# Finding chirps:  31%|███▏      | 10/32 [00:00<00:01, 20.15file/s, Chirps=10, Max Corr=4.64e+02]
# Finding chirps:  41%|████      | 13/32 [00:00<00:00, 19.89file/s, Chirps=10, Max Corr=4.64e+02]
# Finding chirps:  41%|████      | 13/32 [00:00<00:00, 19.89file/s, Chirps=10, Max Corr=5.32e+02]
# Finding chirps:  41%|████      | 13/32 [00:00<00:00, 19.89file/s, Chirps=10, Max Corr=5.18e+02]
# Finding chirps:  41%|████      | 13/32 [00:00<00:00, 19.89file/s, Chirps=10, Max Corr=4.95e+02]
# Finding chirps:  50%|█████     | 16/32 [00:00<00:00, 20.31file/s, Chirps=10, Max Corr=4.95e+02]
# Finding chirps:  50%|█████     | 16/32 [00:00<00:00, 20.31file/s, Chirps=10, Max Corr=5.06e+02]
# Finding chirps:  50%|█████     | 16/32 [00:00<00:00, 20.31file/s, Chirps=10, Max Corr=5.25e+02]
# Finding chirps:  50%|█████     | 16/32 [00:00<00:00, 20.31file/s, Chirps=10, Max Corr=5.05e+02]
# Finding chirps:  59%|█████▉    | 19/32 [00:00<00:00, 20.17file/s, Chirps=10, Max Corr=5.05e+02]
# Finding chirps:  59%|█████▉    | 19/32 [00:00<00:00, 20.17file/s, Chirps=10, Max Corr=4.95e+02]
# Finding chirps:  59%|█████▉    | 19/32 [00:01<00:00, 20.17file/s, Chirps=10, Max Corr=4.86e+02]
# Finding chirps:  59%|█████▉    | 19/32 [00:01<00:00, 20.17file/s, Chirps=10, Max Corr=5.15e+02]
# Finding chirps:  69%|██████▉   | 22/32 [00:01<00:00, 20.45file/s, Chirps=10, Max Corr=5.15e+02]
# Finding chirps:  69%|██████▉   | 22/32 [00:01<00:00, 20.45file/s, Chirps=10, Max Corr=5.21e+02]
# Finding chirps:  69%|██████▉   | 22/32 [00:01<00:00, 20.45file/s, Chirps=10, Max Corr=5.26e+02]
# Finding chirps:  69%|██████▉   | 22/32 [00:01<00:00, 20.45file/s, Chirps=10, Max Corr=5.14e+02]
# Finding chirps:  78%|███████▊  | 25/32 [00:01<00:00, 21.10file/s, Chirps=10, Max Corr=5.14e+02]
# Finding chirps:  78%|███████▊  | 25/32 [00:01<00:00, 21.10file/s, Chirps=10, Max Corr=4.85e+02]
# Finding chirps:  78%|███████▊  | 25/32 [00:01<00:00, 21.10file/s, Chirps=10, Max Corr=5.09e+02]
# Finding chirps:  78%|███████▊  | 25/32 [00:01<00:00, 21.10file/s, Chirps=10, Max Corr=5.14e+02]
# Finding chirps:  88%|████████▊ | 28/32 [00:01<00:00, 21.45file/s, Chirps=10, Max Corr=5.14e+02]
# Finding chirps:  88%|████████▊ | 28/32 [00:01<00:00, 21.45file/s, Chirps=10, Max Corr=4.89e+02]
# Finding chirps:  88%|████████▊ | 28/32 [00:01<00:00, 21.45file/s, Chirps=10, Max Corr=4.85e+02]
# Finding chirps:  88%|████████▊ | 28/32 [00:01<00:00, 21.45file/s, Chirps=10, Max Corr=4.99e+02]
# Finding chirps:  97%|█████████▋| 31/32 [00:01<00:00, 20.70file/s, Chirps=10, Max Corr=4.99e+02]
# Finding chirps:  97%|█████████▋| 31/32 [00:01<00:00, 20.70file/s, Chirps=10, Max Corr=4.84e+02]
# Finding chirps: 100%|██████████| 32/32 [00:01<00:00, 20.38file/s, Chirps=10, Max Corr=4.84e+02]
# ✓ Completed chirp detection: 32 files processed, 320 total chirps found

# %% [markdown]
# ## Find TDOAs

# %%
debug_TDOAs = False

# Find TDOAs for the default propagation mode using the simplified API
# The mode configurations (filter limits, search limits, model coefficients, and plotting params)
# are now stored in hf_tdoa_lib.MODE_CONFIGS

# Process the default mode (2F2-1F2)
chirps = tdoa.find_TDOAs(chirps, mode_string='2F2-1F2',
                        plot_fft=debug_TDOAs, only_one=debug_TDOAs)

# Build the TDOA configuration dictionary with model coefficients and plotting parameters
# Only include the 2F2-1F2 mode for this analysis
tdoa_dct = tdoa.build_tdoa_config(chirps, mode_strings=['2F2-1F2'])

# Print calculated model coefficients for verification
print("Calculated TDOA Model Coefficients:")
print("=" * 60)
for set_name, params in tdoa_dct.items():
    slope, intercept = params['model_coeffs']
    mode_str = params['mode_string']
    print(f"{set_name:12s} ({mode_str:8s}): slope={slope:6.1f}, intercept={intercept:6.1f}")
print("=" * 60)
print()
# Out:
# ======================================================================
# Processing Mode: 2F2-1F2
# ======================================================================
#   Filter Limits:  10.0 - 50.0 Hz
#   Search Window:  -0.10 to 0.10 s offset
#   Freq Range:     11.0 - 20.0 Hz
#   Set Name:       2F2-1F2
#   Sweep Rate:     10 Hz/ms
#   Files to Process: 32
# ======================================================================
# Finding TDOAs (2F2-1F2):   0%|          | 0/32 [00:00<?, ?file/s]
# Finding TDOAs (2F2-1F2):   0%|          | 0/32 [00:00<?, ?file/s, Mean TDOA=1.61 ms]
# Finding TDOAs (2F2-1F2):   3%|▎         | 1/32 [00:00<00:06,  5.08file/s, Mean TDOA=1.61 ms]
# Finding TDOAs (2F2-1F2):   3%|▎         | 1/32 [00:00<00:06,  5.08file/s, Mean TDOA=1.64 ms]
# Finding TDOAs (2F2-1F2):   6%|▋         | 2/32 [00:00<00:06,  4.91file/s, Mean TDOA=1.64 ms]
# Finding TDOAs (2F2-1F2):   6%|▋         | 2/32 [00:00<00:06,  4.91file/s, Mean TDOA=1.68 ms]
# Finding TDOAs (2F2-1F2):   9%|▉         | 3/32 [00:00<00:06,  4.72file/s, Mean TDOA=1.68 ms]
# Finding TDOAs (2F2-1F2):   9%|▉         | 3/32 [00:00<00:06,  4.72file/s, Mean TDOA=1.73 ms]
# Finding TDOAs (2F2-1F2):  12%|█▎        | 4/32 [00:00<00:05,  4.74file/s, Mean TDOA=1.73 ms]
# Finding TDOAs (2F2-1F2):  12%|█▎        | 4/32 [00:01<00:05,  4.74file/s, Mean TDOA=1.88 ms]
# Finding TDOAs (2F2-1F2):  16%|█▌        | 5/32 [00:01<00:05,  4.91file/s, Mean TDOA=1.88 ms]
# Finding TDOAs (2F2-1F2):  16%|█▌        | 5/32 [00:01<00:05,  4.91file/s, Mean TDOA=1.76 ms]
# Finding TDOAs (2F2-1F2):  19%|█▉        | 6/32 [00:01<00:05,  5.01file/s, Mean TDOA=1.76 ms]
# Finding TDOAs (2F2-1F2):  19%|█▉        | 6/32 [00:01<00:05,  5.01file/s, Mean TDOA=1.80 ms]
# Finding TDOAs (2F2-1F2):  22%|██▏       | 7/32 [00:01<00:05,  4.96file/s, Mean TDOA=1.80 ms]
# Finding TDOAs (2F2-1F2):  22%|██▏       | 7/32 [00:01<00:05,  4.96file/s, Mean TDOA=1.82 ms]
# Finding TDOAs (2F2-1F2):  25%|██▌       | 8/32 [00:01<00:04,  4.95file/s, Mean TDOA=1.82 ms]
# Finding TDOAs (2F2-1F2):  25%|██▌       | 8/32 [00:01<00:04,  4.95file/s, Mean TDOA=1.82 ms]
# Finding TDOAs (2F2-1F2):  28%|██▊       | 9/32 [00:01<00:04,  4.95file/s, Mean TDOA=1.82 ms]
# Finding TDOAs (2F2-1F2):  31%|███▏      | 10/32 [00:02<00:04,  4.90file/s, Mean TDOA=1.82 ms]
# Finding TDOAs (2F2-1F2):  31%|███▏      | 10/32 [00:02<00:04,  4.90file/s, Mean TDOA=1.90 ms]
# Finding TDOAs (2F2-1F2):  34%|███▍      | 11/32 [00:02<00:04,  4.88file/s, Mean TDOA=1.90 ms]
# Finding TDOAs (2F2-1F2):  34%|███▍      | 11/32 [00:02<00:04,  4.88file/s, Mean TDOA=1.92 ms]
# Finding TDOAs (2F2-1F2):  38%|███▊      | 12/32 [00:02<00:04,  4.93file/s, Mean TDOA=1.92 ms]
# Finding TDOAs (2F2-1F2):  38%|███▊      | 12/32 [00:02<00:04,  4.93file/s, Mean TDOA=1.79 ms]
# Finding TDOAs (2F2-1F2):  41%|████      | 13/32 [00:02<00:03,  4.94file/s, Mean TDOA=1.79 ms]
# Finding TDOAs (2F2-1F2):  41%|████      | 13/32 [00:02<00:03,  4.94file/s, Mean TDOA=1.75 ms]
# Finding TDOAs (2F2-1F2):  44%|████▍     | 14/32 [00:02<00:03,  4.95file/s, Mean TDOA=1.75 ms]
# Finding TDOAs (2F2-1F2):  44%|████▍     | 14/32 [00:03<00:03,  4.95file/s, Mean TDOA=1.86 ms]
# Finding TDOAs (2F2-1F2):  47%|████▋     | 15/32 [00:03<00:03,  4.95file/s, Mean TDOA=1.86 ms]
# Finding TDOAs (2F2-1F2):  47%|████▋     | 15/32 [00:03<00:03,  4.95file/s, Mean TDOA=1.68 ms]
# Finding TDOAs (2F2-1F2):  50%|█████     | 16/32 [00:03<00:03,  4.98file/s, Mean TDOA=1.68 ms]
# Finding TDOAs (2F2-1F2):  50%|█████     | 16/32 [00:03<00:03,  4.98file/s, Mean TDOA=1.71 ms]
# Finding TDOAs (2F2-1F2):  53%|█████▎    | 17/32 [00:03<00:03,  4.98file/s, Mean TDOA=1.71 ms]
# Finding TDOAs (2F2-1F2):  53%|█████▎    | 17/32 [00:03<00:03,  4.98file/s, Mean TDOA=1.79 ms]
# Finding TDOAs (2F2-1F2):  56%|█████▋    | 18/32 [00:03<00:02,  4.95file/s, Mean TDOA=1.79 ms]
# Finding TDOAs (2F2-1F2):  56%|█████▋    | 18/32 [00:03<00:02,  4.95file/s, Mean TDOA=1.74 ms]
# Finding TDOAs (2F2-1F2):  59%|█████▉    | 19/32 [00:03<00:02,  4.92file/s, Mean TDOA=1.74 ms]
# Finding TDOAs (2F2-1F2):  59%|█████▉    | 19/32 [00:04<00:02,  4.92file/s, Mean TDOA=1.80 ms]
# Finding TDOAs (2F2-1F2):  62%|██████▎   | 20/32 [00:04<00:02,  5.07file/s, Mean TDOA=1.80 ms]
# Finding TDOAs (2F2-1F2):  62%|██████▎   | 20/32 [00:04<00:02,  5.07file/s, Mean TDOA=1.81 ms]
# Finding TDOAs (2F2-1F2):  66%|██████▌   | 21/32 [00:04<00:02,  5.12file/s, Mean TDOA=1.81 ms]
# Finding TDOAs (2F2-1F2):  66%|██████▌   | 21/32 [00:04<00:02,  5.12file/s, Mean TDOA=1.79 ms]
# Finding TDOAs (2F2-1F2):  69%|██████▉   | 22/32 [00:04<00:01,  5.07file/s, Mean TDOA=1.79 ms]
# Finding TDOAs (2F2-1F2):  69%|██████▉   | 22/32 [00:04<00:01,  5.07file/s, Mean TDOA=1.70 ms]
# Finding TDOAs (2F2-1F2):  72%|███████▏  | 23/32 [00:04<00:01,  5.03file/s, Mean TDOA=1.70 ms]
# Finding TDOAs (2F2-1F2):  72%|███████▏  | 23/32 [00:04<00:01,  5.03file/s, Mean TDOA=1.90 ms]
# Finding TDOAs (2F2-1F2):  75%|███████▌  | 24/32 [00:04<00:01,  5.24file/s, Mean TDOA=1.90 ms]
# Finding TDOAs (2F2-1F2):  75%|███████▌  | 24/32 [00:05<00:01,  5.24file/s, Mean TDOA=1.91 ms]
# Finding TDOAs (2F2-1F2):  78%|███████▊  | 25/32 [00:05<00:01,  5.17file/s, Mean TDOA=1.91 ms]
# Finding TDOAs (2F2-1F2):  78%|███████▊  | 25/32 [00:05<00:01,  5.17file/s, Mean TDOA=1.90 ms]
# Finding TDOAs (2F2-1F2):  81%|████████▏ | 26/32 [00:05<00:01,  5.13file/s, Mean TDOA=1.90 ms]
# Finding TDOAs (2F2-1F2):  81%|████████▏ | 26/32 [00:05<00:01,  5.13file/s, Mean TDOA=1.85 ms]
# Finding TDOAs (2F2-1F2):  84%|████████▍ | 27/32 [00:05<00:00,  5.12file/s, Mean TDOA=1.85 ms]
# Finding TDOAs (2F2-1F2):  84%|████████▍ | 27/32 [00:05<00:00,  5.12file/s, Mean TDOA=1.84 ms]
# Finding TDOAs (2F2-1F2):  88%|████████▊ | 28/32 [00:05<00:00,  5.22file/s, Mean TDOA=1.84 ms]
# Finding TDOAs (2F2-1F2):  88%|████████▊ | 28/32 [00:05<00:00,  5.22file/s, Mean TDOA=1.88 ms]
# Finding TDOAs (2F2-1F2):  91%|█████████ | 29/32 [00:05<00:00,  5.14file/s, Mean TDOA=1.88 ms]
# Finding TDOAs (2F2-1F2):  91%|█████████ | 29/32 [00:05<00:00,  5.14file/s, Mean TDOA=1.77 ms]
# Finding TDOAs (2F2-1F2):  94%|█████████▍| 30/32 [00:05<00:00,  5.13file/s, Mean TDOA=1.77 ms]
# Finding TDOAs (2F2-1F2):  94%|█████████▍| 30/32 [00:06<00:00,  5.13file/s, Mean TDOA=1.89 ms]
# Finding TDOAs (2F2-1F2):  97%|█████████▋| 31/32 [00:06<00:00,  5.07file/s, Mean TDOA=1.89 ms]
# Finding TDOAs (2F2-1F2):  97%|█████████▋| 31/32 [00:06<00:00,  5.07file/s, Mean TDOA=1.75 ms]
# Finding TDOAs (2F2-1F2): 100%|██████████| 32/32 [00:06<00:00,  5.00file/s, Mean TDOA=1.75 ms]
# Finding TDOAs (2F2-1F2): 100%|██████████| 32/32 [00:06<00:00,  5.01file/s, Mean TDOA=1.75 ms]
# ✓ Completed processing 2F2-1F2: 32 files processed
#
# Calculated TDOA Model Coefficients:
# ============================================================
# 2F2-1F2      (2F2-1F2 ): slope= 143.0, intercept=  33.0
# ============================================================

# %% [markdown]
# ## Layer Heights Comparison with Ionosonde

# %% [markdown]
# ## Path Information
#
# The `path_info` object provides convenient access to TX/RX coordinates and other path-related calculations.

# %%
# Access the path_info object stored when chirps were created
path_info = chirps.attrs['path_info']

# Display path information
print(f"Path Information:")
print(f"  {path_info}")
print()

# Get TX and RX coordinates from gridsquares
tx_lat, tx_lon = path_info.get_tx_latlon()
rx_lat, rx_lon = path_info.get_rx_latlon()
print(f"TX Location: {tx_lat:.3f}°N, {tx_lon:.3f}°E ({path_info.tx_grid})")
print(f"RX Location: {rx_lat:.3f}°N, {rx_lon:.3f}°E ({path_info.rx_grid})")
print()

# Calculate the great circle midpoint between TX and RX
mid_lat, mid_lon = path_info.get_midpoint()
print(f"Path Midpoint: {mid_lat:.3f}°N, {mid_lon:.3f}°E")
print()

# Calculate the azimuth from TX to RX
azimuth = path_info.get_path_azimuth()
print(f"Path Azimuth (TX→RX): {azimuth:.1f}°")
# Out:
# Path Information:
#   PathInfo(TX: WA5FRF (EL09nn), RX: N5DUP (EM02ch), Range: 318.0 km, Band: 7 MHz)
#
# TX Location: 29.563°N, -98.875°E (EL09nn)
# RX Location: 32.313°N, -99.792°E (EM02ch)
#
# Path Midpoint: 30.938°N, -99.327°E
#
# Path Azimuth (TX→RX): -15.7°

# %% [markdown]
# ## Layer Heights with Solar Elevation and Eclipse Obscuration
#
# The solar coordinates are automatically calculated from the TX/RX path midpoint.

# %%
# Use the path midpoint for solar calculations
solar_lat, solar_lon = path_info.get_midpoint()

# Extract model coefficients from the calculated TDOA dictionary
# These were computed by build_tdoa_config() and represent the best-fit model
model_coeffs = tdoa_dct['2F2-1F2']['model_coeffs']

# Create enhanced plot with solar elevation, eclipse obscuration, and TDOA CSV overlays
tdoa.plot_hmf2(chirps, tdoa_dct,
               solar_lat=solar_lat,
               solar_lon=solar_lon,
               overlay_solar_elevation=True,
               overlay_eclipse=True,
               ionosonde_dct={'overlay_hmE': False},
               tdoa_csv_dct={
                   'csv_path': '../data/CSVs/2024-04-08_TX_WA5FRF_EL09nn-RX_N5DUP_EM02ch-40m_TDOA.csv',
                   'model_coeffs': model_coeffs,
                   'overlay_manual': True,
                   'overlay_autocorr': True,
                   'manual_label': 'Manual Period Analysis',
                   'autocorr_label': 'Auto-Correlated Analysis'
               },
               savefig='fig_11.jpg')
# Out:
# Figure saved to: fig_11.jpg
